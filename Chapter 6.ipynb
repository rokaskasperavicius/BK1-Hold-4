# %%
def find_a_b(x, y):
    if (len(x) != len(y)):
        raise Exception('Length mismatch!')
    
    a = x.cov(y) / x.var()
    
    b = y.mean() - a * x.mean()
    
    return [a, b]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
# Table 6.2

x = pd.Series([250, 300, 350, 470])
y = pd.Series([95, 120, 165, 170])

[a, b] = find_a_b(y, x)

print(f'Slope a = {a} and b = {b}')
# Out:
# Slope a = 2.2993630573248405 and b = 26.33757961783442

# %%
# Table 6.6

x = pd.Series([0.083, 0.115, 0.191, 0.299, 0.501, 0.696, 0.893, 1.084])
y = pd.Series([0, 1, 5, 10, 20, 30, 40, 50])

[a, b] = find_a_b(x, y)

print(f'Slope a = {a} and b = {b}')
# Out:
# Slope a = 50.095120195040614 and b = -4.683419274155856

# %% [markdown]
# ### Exercise 6.3

# %%
timber = pd.read_csv('timber.csv')

# %%
x = timber['Diameter (in)']
y = timber['Volume (cubic feet)']

p = np.polyfit(x, y, 1)

a, b = p

print(f'The slope is a = {a}')
print(f'The intersection is b = {b}')

timber['fit'] = np.polyval(p, x)

timber['residuals'] = y - timber['fit']
# Out:
# The slope is a = 5.065856422843767
# The intersection is b = -36.94345912457855

# %%
plt.figure(figsize = (10, 5))

plt.scatter(
    x = timber['Diameter (in)'],
    y = timber['Volume (cubic feet)'],
)

plt.plot(timber['Diameter (in)'], timber['fit'], '-')

plt.savefig('timber_best_fit.png')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize = (10, 5))

plt.stem(timber['Diameter (in)'], timber['residuals'])

plt.savefig('timber_residuals.png')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Exercise 6.4

# %%
popcorn = pd.read_csv('popcorn.csv')

# %%
x = popcorn['Size (shortest)']
y = popcorn['Size (longest)']

p = np.polyfit(x, y, 1)

a, b = p

print(f'The slope is a = {a}')
print(f'The intersection is b = {b}')

popcorn['fit'] = np.polyval(p, x)

popcorn['residuals'] = y - popcorn['fit']
# Out:
# The slope is a = 1.254039145155742
# The intersection is b = 11.107229722797253

# %%
plt.figure(figsize = (10, 5))

plt.scatter(
    x = popcorn['Size (shortest)'],
    y = popcorn['Size (longest)'],
)

plt.plot(popcorn['Size (shortest)'], popcorn['fit'], '-')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize = (10, 5))

plt.stem(popcorn['Size (shortest)'], popcorn['residuals'])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
