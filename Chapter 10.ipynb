# %%
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import randn
import numpy as np
from scipy import stats
# %matplotlib notebook

# %% [markdown]
# ### Exercise 10.7

# %%
# Define custom normal distribution function to get values for the bell curve
def get_bell_curve_values(u, s):
    y = np.arange(0, 35, 0.1)
    N = np.sqrt(2 * np.pi) * s
    arg = -0.5 * (y - u)**2 / s**2
    f = np.exp(arg) / N
    
    return (y, f)

# %%
N = 1000
u = 17 # Mean, mu

# Standart deviation list, sigma
s_list = [2, 4, 8]

# Loop through sigma list and show three different plots
for s in s_list:

    # Generating data with sigma value
    data = pd.Series(randn(N) * s + u)

    # Plotting
    plt.figure(figsize=[10, 5])
    plt.title(f'Normal Distribution with mean = {u} and sigma = {s}')

    plt.hist(data, density=True, bins=np.arange(0, 35, 1.0))

    (y, f) = get_bell_curve_values(u, s)

    plt.plot(y, f, 'r-')

    plt.xlabel('Meassured value')
    plt.ylabel('Distribution')
    
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# From the graphs above you can notice that with a larger sigma value, the width of the normal distribution is also larger.

# %% [markdown]
# ### Exercise 10.8

# %%
popcorn_df = pd.read_csv('popcorn.csv')

longest_size = popcorn_df['Size (longest)']

u = longest_size.mean()
s = longest_size.std()

y = np.arange(0, 50, 0.1)
N = np.sqrt(2 * np.pi) * s
arg = -0.5 * (y - u)**2 / s**2
f = np.exp(arg) / N

# Plotting
plt.figure(figsize=[10, 5])
plt.title('Distribution of popcorn width')

plt.hist(longest_size, density=True)
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.plot(y, f, 'r-')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Exercise 10.9

# %%
# 10.9.1

u = 22.6
s = 2.4

data = pd.Series(randn(10) * s + u)

data.sort_values()

mean = data.mean()
standart_deviation = data.std()

print(mean, standart_deviation) # 1st rule of Assesing Normality

# 2nd, 3rd and 4th rules of Assesing Normality
plt.figure(figsize=[10, 5])

data.plot.box()

plt.show()
# Out:
# 21.603887310730848 2.85869777771969
# <img src="data:image/png;base64,..." width="1000">

# %%
# 10.9.2

data = []

for n in [10, 100, 1000, 10000]:
    data = pd.Series(randn(n) * s + u)
    
    u = data.mean()
    s = data.std()
    
    print(f'N = {n} \n')
    
    print(f'Mean (u) = {u}, Standart Deviation (s) = {s}, Standart Error (Or standart deviation of the sample mean) = {u / np.sqrt(n)} \n')
# Out:
# N = 10
#
# Mean (u) = 23.36737492536819, Standart Deviation (s) = 2.831072639436046, Standart Error (Or standart deviation of the sample mean) = 7.389412770327057
#
# N = 100
#
# Mean (u) = 23.300800200676306, Standart Deviation (s) = 3.0532723126065378, Standart Error (Or standart deviation of the sample mean) = 2.330080020067631
#
# N = 1000
#
# Mean (u) = 23.228938965523742, Standart Deviation (s) = 2.9106139255399563, Standart Error (Or standart deviation of the sample mean) = 0.7345635476009051
#
# N = 10000
#
# Mean (u) = 23.230521499127065, Standart Deviation (s) = 2.911258175721005, Standart Error (Or standart deviation of the sample mean) = 0.23230521499127066

# %% [markdown]
# ### Exercise 10.10

# %%
data = pd.Series([33, 26, 34, 31, 23, 25])

u = data.mean()
s = data.std()

# 10.10.1
print(f'Standart Error = {u / len(data)**0.5} \n')

# 10.10.2
t0975 = 2

SEy = s / len(data)**0.5

delta_mean = t0975 * SEy

print(f'The lower limit of the 95% confidence interval is {u - delta_mean}')
print(f'The upper limit of the 95% confidence interval is {u + delta_mean} \n')

# 10.10.3
t0835 = 1

SEy = s / len(data)**0.5

delta_mean = t0835 * SEy

print(f'The lower limit of the 67% confidence interval is {u - delta_mean}')
print(f'The upper limit of the 67% confidence interval is {u + delta_mean}')
# Out:
# Standart Error = 11.703117659964075
#
# The lower limit of the 95% confidence interval is 24.919074847318615
# The upper limit of the 95% confidence interval is 32.414258486014724
#
# The lower limit of the 67% confidence interval is 26.79287075699264
# The upper limit of the 67% confidence interval is 30.540462576340694
