# %%
import pandas as pd
from numpy.random import randn
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
u = 22.6
s = 2.4

n = 10

data = pd.Series(randn(n) * s + u)

print(data.sort_values())

print(data.mean())
print(data.std())
# Out:
# 480    14.635098
# 930    14.636032
# 238    14.817743
# 606    16.270076
# 21     16.834952
#          ...
# 909    29.490210
# 486    30.035220
# 143    30.171544
# 821    30.782462
# 131    31.953001
# Length: 1000, dtype: float64
# 22.540021135434
# 2.3893166831016956

# %%
data.plot.box()
# Out:
# <AxesSubplot:>

# %%
# Exercise 10.9.2

n_list = [10, 100, 1000]
u = 22.6
s = 2.4
experiment_count = 100

for n in n_list:
    mean_list = pd.DataFrame(s * randn(experiment_count, n) + u).mean(axis ='columns')
    
    # Plotting time
    plt.figure(figsize=[10, 5])
    plt.title(f'Mean spread with n = {n}')
    
    plt.hist(mean_list, bins = np.arange(20, 25, 0.2))
    
    plt.xlabel('Mean')
    plt.ylabel('Frequency')
    
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
